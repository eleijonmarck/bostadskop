# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1,10,100)
f = np.power(x,gamma) / (gamma)

# %% [markdown]
# ## The power curve for a different mindset of people for their spendings
#
# Antons philosophy of utility function for a life span
# * A pokerplayer want to have mindset of close to **zero** for gamma.
# * A normal person usually tends to be gamma < 0 depending on your risk taking.

# %%
gamma = 0.00001
plt.plot(x,f)

# %% [markdown]
# Plot of a poker players utility function

# %%
gamma = 0.61
plt.plot(x,f)

# %% [markdown]
# Plot of a normal persons utility function
